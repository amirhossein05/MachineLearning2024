# %% [markdown]
# # Problem 1
# ## McCulloch_Pitts

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define McCulloch-Pitts neuron class
class McCulloch_Pitts_neuron():

    def __init__(self, weights, threshold):
        self.weights = weights    # define weights
        self.threshold = threshold    # define threshold

    def model(self, x):
        # define model with threshold
        if self.weights @ x >= self.threshold:
            return 1
        else:
            return 0

# %%
# Define function to classify points
def Area(x, y):
    # Define neurons for each vertex of the triangle
    neur1 = McCulloch_Pitts_neuron([2, -1], 2)  # Vertex A
    neur2 = McCulloch_Pitts_neuron([-2, -1], -6)  # Vertex B
    neur3 = McCulloch_Pitts_neuron([0, 1], 0)  # Vertex C
    neur4 = McCulloch_Pitts_neuron([1, 1, 1], 3)

    # Evaluate output of each neuron
    z1 = (neur1.model(np.array([x, y])))
    z2 = (neur2.model(np.array([x, y])))
    z3 = (neur3.model(np.array([x, y])))
    z4 = (neur4.model(np.array([z1, z2, z3])))
    
    return list([z4])

# %%
# Generate random data points
num_points = 2000
np.random.seed(94)

x_values = np.random.uniform(0, 4, num_points)
y_values = np.random.uniform(-1, 3, num_points)
# Initialize lists to store data points for different z5 values
red_points = []
green_points = []

# Evaluate data points using the Area function
for i in range(num_points):
    z4_value = Area(x_values[i], y_values[i])
    if z4_value == [0]:  # z5 value is 0
        red_points.append((x_values[i], y_values[i]))
    else:  # z5 value is 1
        green_points.append((x_values[i], y_values[i]))

# Separate x and y values for red and green points
red_x, red_y = zip(*red_points)
green_x, green_y = zip(*green_points)

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Graph with Lines and Hatched Area (Triangle)')
plt.plot([1, 3, 2, 1], [0, 0, 2, 0], 'b-', label='Triangle Vertices')
plt.show()

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(red_x, red_y, color='red', label='Outside Triangle')
plt.scatter(green_x, green_y, color='green', label='Inside Triangle')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('McCulloch-Pitts Neuron Outputs')

# Plotting vertices of the triangle
plt.plot([1, 3, 2, 1], [0, 0, 2, 0], 'b-', label='Triangle Vertices')

plt.grid(True)

# Set axis limits
plt.xlim(0, 4)
plt.ylim(-1, 3)

# Position the legends at the top and right
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.0))

plt.show()

# %% [markdown]
# ### Use different activation functions

# %%
# Activation Function
def relu(x):
    return np.maximum(0, x)
def sigmoid(x):
    return 1/(1+np.exp(-x))
def tanh(x):
    return np.tanh(x)

# %%
# Define McCulloch-Pitts neuron class
class McCulloch_Pitts_neuron():

    def __init__(self, weights, threshold):
        self.weights = weights    # define weights
        self.threshold = threshold    # define threshold

    def model(self, x):
        # define model with threshold
        if sigmoid(self.weights @ x) >= sigmoid(self.threshold):
            return 1
        else:
            return 0

# %%
# Define function to classify points
def Area(x, y):
    # Define neurons for each vertex of the triangle
    neur1 = McCulloch_Pitts_neuron([2, -1], 2)  # Vertex A
    neur2 = McCulloch_Pitts_neuron([-2, -1], -6)  # Vertex B
    neur3 = McCulloch_Pitts_neuron([0, 1], 0)  # Vertex C
    neur4 = McCulloch_Pitts_neuron([1, 1, 1], 3)

    # Evaluate output of each neuron
    z1 = (neur1.model(np.array([x, y])))
    z2 = (neur2.model(np.array([x, y])))
    z3 = (neur3.model(np.array([x, y])))
    z4 = (neur4.model(np.array([z1, z2, z3])))
    
    return list([z4])

# %%
# Generate random data points
num_points = 2000
np.random.seed(94)

x_values = np.random.uniform(0, 4, num_points)
y_values = np.random.uniform(-1, 3, num_points)
# Initialize lists to store data points for different z5 values
red_points = []
green_points = []

# Evaluate data points using the Area function
for i in range(num_points):
    z4_value = Area(x_values[i], y_values[i])
    if z4_value == [0]:  # z5 value is 0
        red_points.append((x_values[i], y_values[i]))
    else:  # z5 value is 1
        green_points.append((x_values[i], y_values[i]))

# Separate x and y values for red and green points
red_x, red_y = zip(*red_points)
green_x, green_y = zip(*green_points)

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(red_x, red_y, color='red', label='Outside Triangle')
plt.scatter(green_x, green_y, color='green', label='Inside Triangle')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('McCulloch-Pitts Neuron Outputs With Tanh Activation')

# Plotting vertices of the triangle
plt.plot([1, 3, 2, 1], [0, 0, 2, 0], 'b-', label='Triangle Vertices')

plt.grid(True)

# Set axis limits
plt.xlim(0, 4)
plt.ylim(-1, 3)

# Position the legends at the top and right
plt.legend(loc='upper right', bbox_to_anchor=(1.2, 1.0))

plt.show()

# %% [markdown]
# # Problem 2
# ## CWRU Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# load dataset
# !pip install gdown
# !gdown 1sGmbAgIHJK0MgLUQv5E1jzUNTadLtSkL
# !gdown 1vV8IQLMV3LP4C-g1vlaG6wbjakmMitcF
# !gdown 1byknpD4FHozQX4b4NY1PVhuqJ-su37AG
# !gdown 1vfbZan9620nPO33DOVkR6I61Rjbpcz8G
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1sGmbAgIHJK0MgLUQv5E1jzUNTadLtSkL
# From (redirected): https://drive.google.com/uc?id=1sGmbAgIHJK0MgLUQv5E1jzUNTadLtSkL&confirm=t&uuid=309446c3-a6d8-44ce-bc75-29ab526af498
# To: /home/amirhosseion/Pr#2/Normal_2.mat
# 100%|███████████████████████████████████████| 15.5M/15.5M [00:29<00:00, 527kB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1vV8IQLMV3LP4C-g1vlaG6wbjakmMitcF
# From (redirected): https://drive.google.com/uc?id=1vV8IQLMV3LP4C-g1vlaG6wbjakmMitcF&confirm=t&uuid=0825bbac-b623-40e7-a4b0-17334c784302
# To: /home/amirhosseion/Pr#2/IR007_2.mat
# 100%|███████████████████████████████████████| 2.93M/2.93M [00:06<00:00, 481kB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1byknpD4FHozQX4b4NY1PVhuqJ-su37AG
# From (redirected): https://drive.google.com/uc?id=1byknpD4FHozQX4b4NY1PVhuqJ-su37AG&confirm=t&uuid=e59072e1-47c5-43ba-8f12-818d5c05940f
# ...

# %%
import scipy.io as sio
Normal = sio.loadmat('Normal_2.mat') # Load the .mat file
Fault_1 = sio.loadmat('IR007_2.mat')
Fault_2 = sio.loadmat('B007_2.mat')
Fault_3 = sio.loadmat('OR007@6_2.mat')

# %%
# Define the number of samples (M) and length of each sample (N)
M = 100  # at least 100 samples
N = 200  # at least 200 data points per sample
# Normal Class
# Extract M samples of length N from each class
normal_class_data = {}  # Dictionary to hold data for each class

for key in Normal.keys():
    if key.endswith('X098_DE_time'):  # Assuming the classes X098_DE_time
        class_name = key  # Full name of the class
        if class_name not in normal_class_data:
            normal_class_data[class_name] = []
        
        # Extract M samples of length N
        samples = []
        for i in range(M):
            start_index = np.random.randint(0, len(Normal[key]) - N)
            sample = Normal[key][start_index:start_index + N]
            samples.append(sample)
        
        normal_class_data[class_name] = samples


# Combine the data and labels into a single matrix
normal_class = np.vstack([np.array(samples) for samples in normal_class_data.values()])
normal_class = np.squeeze(normal_class) # reshape normal_matrix to MxN matrix
print("Normal Class Matrix Shape:", normal_class.shape)  # Print the shapes of the normal_class matrix
# Out:
# Normal Class Matrix Shape: (100, 200)

# %%
# Extract M samples of length N from each class
fault_class_data = {}  # Dictionary to hold data for each class

for key in Fault_1.keys():
    if key.endswith('107_DE_time'):  # Assuming the classes X107_DE_time
        class_name = key  # Full name of the class
        if class_name not in fault_class_data:
            fault_class_data[class_name] = []
        
        # Extract M samples of length N
        samples = []
        for i in range(M):
            start_index = np.random.randint(0, len(Fault_1[key]) - N)
            sample = Fault_1[key][start_index:start_index + N]
            samples.append(sample)
        
        fault_class_data[class_name] = samples

# Combine the data and labels into a single matrix
fault_class_1 = np.vstack([np.array(samples) for samples in fault_class_data.values()])
fault_class_1 = np.squeeze(fault_class_1) # reshape normal_matrix to MxN matrix
print(fault_class_1.shape)  # Print the shapes of the normal_class matrix
# Out:
# (100, 200)

# %%
# Extract M samples of length N from each class
fault_class_data = {}  # Dictionary to hold data for each class

for key in Fault_2.keys():
    if key.endswith('X120_FE_time'):  # Assuming the classes X107_DE_time
        class_name = key  # Full name of the class
        if class_name not in fault_class_data:
            fault_class_data[class_name] = []
        
        # Extract M samples of length N
        samples = []
        for i in range(M):
            start_index = np.random.randint(0, len(Fault_2[key]) - N)
            sample = Fault_2[key][start_index:start_index + N]
            samples.append(sample)
        
        fault_class_data[class_name] = samples

# Combine the data and labels into a single matrix
fault_class_2 = np.vstack([np.array(samples) for samples in fault_class_data.values()])
fault_class_2 = np.squeeze(fault_class_2) # reshape normal_matrix to MxN matrix
print(fault_class_2.shape)  # Print the shapes of the normal_class matrix
# Out:
# (100, 200)

# %%
# Extract M samples of length N from each class
fault_class_data = {}  # Dictionary to hold data for each class

for key in Fault_3.keys():
    if key.endswith('X132_FE_time'):  # Assuming the classes X107_DE_time
        class_name = key  # Full name of the class
        if class_name not in fault_class_data:
            fault_class_data[class_name] = []
        
        # Extract M samples of length N
        samples = []
        for i in range(M):
            start_index = np.random.randint(0, len(Fault_3[key]) - N)
            sample = Fault_3[key][start_index:start_index + N]
            samples.append(sample)
        
        fault_class_data[class_name] = samples

# Combine the data and labels into a single matrix
fault_class_3 = np.vstack([np.array(samples) for samples in fault_class_data.values()])
fault_class_3 = np.squeeze(fault_class_3) # reshape normal_matrix to MxN matrix
print(fault_class_3.shape)  # Print the shapes of the normal_class matrix
# Out:
# (100, 200)

# %% [markdown]
# ### Feature Extraction

# %%
import numpy as np
import scipy.stats

# %%
# Define a function to calculate each feature
def extract_features(data_matrix):
    features = []
    
    # Calculate mean
    mean = np.mean(data_matrix, axis=1)
    features.append(mean)
    
    # Calculate peak
    peak = np.max(data_matrix, axis=1)
    features.append(peak)
    
    # Calculate standard deviation
    std_dev = np.std(data_matrix, axis=1)
    features.append(std_dev)
    
    # Calculate kurtosis
    kurtosis = scipy.stats.kurtosis(data_matrix, axis=1)
    features.append(kurtosis)

    # Calculate absolute mean
    abs_mean = np.mean(np.abs(data_matrix), axis=1)
    features.append(abs_mean)
    
    # Calculate impact factor
    impact_factor = peak / abs_mean
    features.append(impact_factor)
    
    # Calculate square_mean_root
    smr = (np.mean(np.sqrt(np.abs(data_matrix)), axis=1))**2
    features.append(smr)
    
    # Calculate crest factor
    crest_factor = peak / smr
    features.append(crest_factor)
    
   
    
    return np.array(features).T  # Transpose to have features as columns

# Perform feature extraction
extracted_features_normal_class = extract_features(normal_class)
extracted_features_fault_class_1 = extract_features(fault_class_1)
extracted_features_fault_class_2 = extract_features(fault_class_2)
extracted_features_fault_class_3 = extract_features(fault_class_3)


# Print the shape of the extracted features matrix
print("Extracted Features Shape of Noraml class:", extracted_features_normal_class.shape)
print("Extracted Features Shape of Fault class IR007_2:", extracted_features_fault_class_1.shape)
print("Extracted Features Shape of Fault class B007_2:", extracted_features_fault_class_2.shape)
print("Extracted Features Shape of Fault class OR007@6_2:", extracted_features_fault_class_3.shape)
# Out:
# Extracted Features Shape of Noraml class: (100, 8)
# Extracted Features Shape of Fault class IR007_2: (100, 8)
# Extracted Features Shape of Fault class B007_2: (100, 8)
# Extracted Features Shape of Fault class OR007@6_2: (100, 8)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Assuming normal_class is your data matrix and labels_matrix is the corresponding labels matrix

# Shuffle the data and labels together
indices = np.arange(normal_class.shape[0])
indices_1 = np.arange(fault_class_1.shape[0])
indices_2 = np.arange(fault_class_2.shape[0])
indices_3 = np.arange(fault_class_3.shape[0])

np.random.shuffle(indices)
np.random.shuffle(indices_1)
np.random.shuffle(indices_2)
np.random.shuffle(indices_3)

shuffled_normal_class = normal_class[indices]
shuffled_fault_class_1 = fault_class_1[indices_1]
shuffled_fault_class_2 = fault_class_2[indices_2]
shuffled_fault_class_3 = fault_class_3[indices_3]

# Create labels for normal and fault classes (0 for normal, 1 for fault)
normal_labels = np.zeros(normal_class.shape[0])
fault_labels_1 = np.ones(fault_class_1.shape[0])
fault_labels_2 = np.ones(fault_class_2.shape[0])
fault_labels_3 = np.ones(fault_class_3.shape[0])


# Combine the data matrices and labels
X = np.vstack((normal_class, fault_class_1, fault_class_2, fault_class_3))
y = np.concatenate((normal_labels, fault_labels_1, fault_labels_2, fault_labels_3))
# Split the shuffled data into training and evaluation sets with a 80-20 ratio
# Step 1: Splitting the data into training and remaining data
x_train, x_remaining, y_train, y_remaining = train_test_split(X, y, test_size=0.2, random_state=94)

# Step 2: Splitting the remaining data into validation and testing sets
x_val, x_test, y_val, y_test = train_test_split(x_remaining, y_remaining, test_size=0.5, random_state=94)
# Print the shapes of the training and evaluation sets
print("Training data Class Shape:", x_train.shape)
print("Training label Class Shape:", y_train.shape)
print("Evaluation data Class Shape:", x_test.shape)
print("Evaluation labe Class Shape:", y_test.shape)
# Out:
# Training data Class Shape: (320, 200)
# Training label Class Shape: (320,)
# Evaluation data Class Shape: (40, 200)
# Evaluation labe Class Shape: (40,)

# %%
#reshape label shape
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1,1)
print("Training label Class Shape:", y_train.shape)
print("Evaluation labe Class Shape:", y_test.shape)
# Out:
# Training label Class Shape: (320, 1)
# Evaluation labe Class Shape: (40, 1)

# %%
# Normalizaion
from sklearn.preprocessing import StandardScaler
#Z-score normalization
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and evaluation data
train_data_normalized = scaler.fit_transform(x_train)
eval_data_normalized = scaler.transform(x_test)

# Print the shapes of the normalized training and evaluation data
print("Normalized Training Data Shape:", train_data_normalized.shape)
print("Normalized Evaluation Data Shape:", eval_data_normalized.shape)
# Out:
# Normalized Training Data Shape: (320, 200)
# Normalized Evaluation Data Shape: (40, 200)

# %% [markdown]
# ### MLP

# %%
from sklearn.neural_network import MLPClassifier, MLPRegressor

from imblearn.under_sampling import RandomUnderSampler

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

import numpy as np

# %%
# Count the number of samples in each class
unique, counts = np.unique(y, return_counts=True)
print("Class counts before balancing:", dict(zip(unique, counts)))

# Use RandomUnderSampler to balance the classes
rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X, y)

# Count the number of samples in each class after balancing
unique_resampled, counts_resampled = np.unique(y_resampled, return_counts=True)
print("Class counts after balancing:", dict(zip(unique_resampled, counts_resampled)))
print('\n')
print("New balanced dataset shape:", X_resampled.shape, y_resampled.shape)
# Out:
# Class counts before balancing: {0.0: 100, 1.0: 300}
# Class counts after balancing: {0.0: 100, 1.0: 100}
#
#
# New balanced dataset shape: (200, 200) (200,)

# %%
unique
# Out:
# array([0., 1.])

# %%
counts
# Out:
# array([100, 300])

# %%
dict(zip(unique, counts))
# Out:
# {0.0: 100, 1.0: 300}

# %%
X = X_resampled
y = y_resampled
print(X.shape, y.shape)
# Out:
# (200, 200) (200,)

# %%
# Step 1: Splitting the data into training and remaining data
x_train, x_remaining, y_train, y_remaining = train_test_split(X, y, test_size=0.2, random_state=94)

# Step 2: Splitting the remaining data into validation and testing sets
x_val, x_test, y_val, y_test = train_test_split(x_remaining, y_remaining, test_size=0.5, random_state=94)

# %%
x_val.shape
# Out:
# (20, 200)

# %%
# model = MLPClassifier(hidden_layer_sizes=(10, 5, 2), random_state=94, verbose = True)
# model.fit(x_train, y_train)
# model.score(x_test, y_test)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Assuming you've trained your model already
model = MLPClassifier(hidden_layer_sizes=(8,4,2), random_state=94, activation='relu', solver='adam')
model.fit(x_train, y_train)

# Making predictions on the test set
y_pred = model.predict(x_test)

# Calculating confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)

# Creating confusion matrix display
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])

# Plotting confusion matrix
cm_display.plot()

# Adjusting plot labels
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')


# Printing classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /home/amirhosseion/miniconda3/envs/TestPy/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91        10
#          1.0       1.00      0.80      0.89        10
#
#     accuracy                           0.90        20
#    macro avg       0.92      0.90      0.90        20
# weighted avg       0.92      0.90      0.90        20

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# Initialize the model
model = MLPClassifier(hidden_layer_sizes=(8, 4, 2), random_state=94, activation='relu', solver='adam', warm_start=True)

# Lists to store loss and accuracy values
loss_values = []
accuracy_values = []

# Number of iterations
n_iterations = 200

# Training loop for each iteration
for iteration in range(n_iterations):
    # Train model for one iteration
    model.partial_fit(x_train, y_train, classes=np.unique(y_train))
    
    # Record loss
    if hasattr(model, 'loss_'):
        loss_values.append(model.loss_)
    
    # Predict on the test set
    y_pred = model.predict(x_test)
    
    # Record accuracy
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_values.append(accuracy)
    
    print(f"Iteration {iteration+1}/{n_iterations} - Loss: {model.loss_:.4f}, Accuracy: {accuracy:.4f}")

# Plotting the loss curve
plt.figure(figsize=(10, 6))
plt.plot(loss_values, label='Training Loss')
plt.title('Model Loss During Training')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('training_loss_curve.png', dpi=300)
plt.show()

# Plotting the accuracy curve
plt.figure(figsize=(10, 6))
plt.plot(accuracy_values, label='Training Accuracy', color='orange')
plt.title('Model Accuracy During Training')
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('training_accuracy_curve.png', dpi=300)
plt.show()

# Final accuracy
final_accuracy = accuracy_values[-1]
print(f"Final Model Accuracy: {final_accuracy * 100:.2f}%")
# Out:
# Iteration 1/200 - Loss: 0.7375, Accuracy: 0.5000
# Iteration 2/200 - Loss: 0.7341, Accuracy: 0.5000
# Iteration 3/200 - Loss: 0.7307, Accuracy: 0.5000
# Iteration 4/200 - Loss: 0.7273, Accuracy: 0.5000
# Iteration 5/200 - Loss: 0.7239, Accuracy: 0.5000
# Iteration 6/200 - Loss: 0.7204, Accuracy: 0.5000
# Iteration 7/200 - Loss: 0.7170, Accuracy: 0.5000
# Iteration 8/200 - Loss: 0.7135, Accuracy: 0.5000
# Iteration 9/200 - Loss: 0.7101, Accuracy: 0.5000
# Iteration 10/200 - Loss: 0.7067, Accuracy: 0.5000
# Iteration 11/200 - Loss: 0.7033, Accuracy: 0.5000
# Iteration 12/200 - Loss: 0.6999, Accuracy: 0.5000
# Iteration 13/200 - Loss: 0.6965, Accuracy: 0.5000
# Iteration 14/200 - Loss: 0.6930, Accuracy: 0.5000
# Iteration 15/200 - Loss: 0.6896, Accuracy: 0.5000
# Iteration 16/200 - Loss: 0.6862, Accuracy: 0.5000
# Iteration 17/200 - Loss: 0.6828, Accuracy: 0.5000
# Iteration 18/200 - Loss: 0.6794, Accuracy: 0.5000
# Iteration 19/200 - Loss: 0.6761, Accuracy: 0.5000
# ...

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# Initialize the model
model = MLPClassifier(hidden_layer_sizes=(8, 4, 2), random_state=94, activation='relu', solver='adam', warm_start=True)

# Lists to store loss and accuracy values
loss_values = []
accuracy_values = []

# Number of iterations
n_iterations = 200

# Training loop for each iteration
for iteration in range(n_iterations):
    # Train model for one iteration
    model.partial_fit(x_train, y_train, classes=np.unique(y_train))
    
    # Record loss
    if hasattr(model, 'loss_'):
        loss_values.append(model.loss_)
    
    # Predict on the test set
    y_pred = model.predict(x_val)
    
    # Record accuracy
    accuracy = accuracy_score(y_val, y_pred)
    accuracy_values.append(accuracy)
    
    print(f"Iteration {iteration+1}/{n_iterations} - Loss: {model.loss_:.4f}, Accuracy: {accuracy:.4f}")

# Plotting the loss curve
plt.figure(figsize=(10, 6))
plt.plot(loss_values, label='Validation Loss')
plt.title('Model Loss During Validation')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# Plotting the accuracy curve
plt.figure(figsize=(10, 6))
plt.plot(accuracy_values, label='Validation Accuracy', color='orange')
plt.title('Model Accuracy Validation')
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# Final accuracy
final_accuracy = accuracy_values[-1]
print(f"Final Model Accuracy: {final_accuracy * 100:.2f}%")
# Out:
# Iteration 1/200 - Loss: 0.7375, Accuracy: 0.4500
# Iteration 2/200 - Loss: 0.7341, Accuracy: 0.4500
# Iteration 3/200 - Loss: 0.7307, Accuracy: 0.4500
# Iteration 4/200 - Loss: 0.7273, Accuracy: 0.4500
# Iteration 5/200 - Loss: 0.7239, Accuracy: 0.4500
# Iteration 6/200 - Loss: 0.7204, Accuracy: 0.4500
# Iteration 7/200 - Loss: 0.7170, Accuracy: 0.4500
# Iteration 8/200 - Loss: 0.7135, Accuracy: 0.4500
# Iteration 9/200 - Loss: 0.7101, Accuracy: 0.4500
# Iteration 10/200 - Loss: 0.7067, Accuracy: 0.4500
# Iteration 11/200 - Loss: 0.7033, Accuracy: 0.4500
# Iteration 12/200 - Loss: 0.6999, Accuracy: 0.4500
# Iteration 13/200 - Loss: 0.6965, Accuracy: 0.4500
# Iteration 14/200 - Loss: 0.6930, Accuracy: 0.4500
# Iteration 15/200 - Loss: 0.6896, Accuracy: 0.4500
# Iteration 16/200 - Loss: 0.6862, Accuracy: 0.4500
# Iteration 17/200 - Loss: 0.6828, Accuracy: 0.4500
# Iteration 18/200 - Loss: 0.6794, Accuracy: 0.4500
# Iteration 19/200 - Loss: 0.6761, Accuracy: 0.4500
# ...

# %% [markdown]
# ### repeat the same thing with another activation function

# %%
x_train.shape
# Out:
# (100, 10)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, mean_squared_error, accuracy_score

# Define custom accuracy function
def accuracy(y_true, y_pred, threshold=0.5):
    y_pred_label = (y_pred >= threshold).astype(int)
    return np.mean(y_true == y_pred_label)



# Initialize MLPRegressor with sigmoid activation and max_iter=1 for manual iteration
model = MLPRegressor(hidden_layer_sizes=(8, 4, 2), activation='logistic', solver='adam', max_iter=1, warm_start=True)

# Lists to store loss and accuracy values
loss_history = []
accuracy_history = []

# Number of iterations
n_iterations = 200

# Training loop for each iteration
for iteration in range(n_iterations):
    # Train model for one iteration
    model.fit(x_train, y_train.ravel())
    
    # Record loss
    if hasattr(model, 'loss_'):
        loss_history.append(model.loss_)
    
    # Predict on the test set
    y_pred = model.predict(x_train)
    
    # Record accuracy
    acc = accuracy(y_train, y_pred)
    accuracy_history.append(acc)
    
    if iteration % 10 == 0:
        print(f"Iteration {iteration+1}/{n_iterations} - Loss: {model.loss_:.4f}, Accuracy: {acc:.4f}")

# Plotting the training loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(loss_history, label='Traning Loss')
plt.title('Loss Curve During Traning')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

# Plotting the training accuracy
plt.subplot(1, 2, 2)
plt.plot(accuracy_history, label='Traning Accuracy')
plt.title('Accuracy Curve During Traning')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# Predict and plot confusion matrix
y_pred_class = (model.predict(x_test) >= 0.5).astype(int)
cm = confusion_matrix(y_test, y_pred_class)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
# Printing classification report
print("Classification Report:")
print(classification_report(y_test, y_pred_class))
# Out:
# /home/amirhosseion/miniconda3/envs/TestPy/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/amirhosseion/miniconda3/envs/TestPy/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/amirhosseion/miniconda3/envs/TestPy/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ### Stratified K-Fold Cross-validation

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import  StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=10)
skf_accuracies = []

for train_index, test_index in skf.split(X, y):
    x_train, x_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    model = MLPClassifier(hidden_layer_sizes=(8,4,2), random_state=94, activation='relu', solver='adam')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    skf_accuracies.append(accuracy_score(y_test, y_pred))

print("Stratified K-Fold Cross-Validation Accuracies:", skf_accuracies)
print("Average Accuracy:", np.mean(skf_accuracies))
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
# Creating confusion matrix display
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])

# Plotting confusion matrix
cm_display.plot()

# Adjusting plot labels
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
# Printing classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /home/amirhosseion/miniconda3/envs/TestPy/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/amirhosseion/miniconda3/envs/TestPy/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/amirhosseion/miniconda3/envs/TestPy/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
# Lists to store loss and accuracy values
loss_values = []
accuracy_values = []

# Number of iterations
n_iterations = 200

# Training loop for each iteration
for iteration in range(n_iterations):
    # Train model for one iteration
    model.partial_fit(x_train, y_train, classes=np.unique(y_train))
    
    # Record loss
    if hasattr(model, 'loss_'):
        loss_values.append(model.loss_)
    
    # Predict on the test set
    y_pred = model.predict(x_val)
    
    # Record accuracy
    accuracy = accuracy_score(y_val, y_pred)
    accuracy_values.append(accuracy)
    
    print(f"Iteration {iteration+1}/{n_iterations} - Loss: {model.loss_:.4f}, Accuracy: {accuracy:.4f}")

# Plotting the loss curve
plt.figure(figsize=(10, 6))
plt.plot(loss_values, label='Validation Loss')
plt.title('Model Loss During Validation')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# Plotting the accuracy curve
plt.figure(figsize=(10, 6))
plt.plot(accuracy_values, label='Validation Accuracy', color='orange')
plt.title('Model Accuracy Validation')
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# Final accuracy
final_accuracy = accuracy_values[-1]
print(f"Final Model Accuracy: {final_accuracy * 100:.2f}%")
# Out:
# Iteration 1/200 - Loss: 0.2571, Accuracy: 0.9250
# Iteration 2/200 - Loss: 0.2553, Accuracy: 0.9500
# Iteration 3/200 - Loss: 0.2536, Accuracy: 0.9500
# Iteration 4/200 - Loss: 0.2519, Accuracy: 0.9500
# Iteration 5/200 - Loss: 0.2502, Accuracy: 0.9500
# Iteration 6/200 - Loss: 0.2485, Accuracy: 0.9500
# Iteration 7/200 - Loss: 0.2468, Accuracy: 0.9500
# Iteration 8/200 - Loss: 0.2451, Accuracy: 0.9500
# Iteration 9/200 - Loss: 0.2434, Accuracy: 0.9500
# Iteration 10/200 - Loss: 0.2417, Accuracy: 0.9500
# Iteration 11/200 - Loss: 0.2400, Accuracy: 0.9500
# Iteration 12/200 - Loss: 0.2383, Accuracy: 0.9500
# Iteration 13/200 - Loss: 0.2366, Accuracy: 0.9500
# Iteration 14/200 - Loss: 0.2349, Accuracy: 0.9500
# Iteration 15/200 - Loss: 0.2333, Accuracy: 0.9500
# Iteration 16/200 - Loss: 0.2316, Accuracy: 0.9500
# Iteration 17/200 - Loss: 0.2300, Accuracy: 0.9500
# Iteration 18/200 - Loss: 0.2283, Accuracy: 0.9500
# Iteration 19/200 - Loss: 0.2267, Accuracy: 0.9500
# ...

# %% [markdown]
# # Problem 3
# ## Decision Trees

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, ConfusionMatrixDisplay

# %%
# !pip install gdown
# !gdown 1EXTYn5PZMZSym_LJDfRmE2z4crrhrTfe
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 123.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 525.4 kB/s eta 0:00:00a 0:00:01
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1EXTYn5PZMZSym_LJDfRmE2z4crrhrTfe
# To: /home/amirhosseion/Pr#2/drug200.csv
# 100%|███████████████████████████████████████| 5.83k/5.83k [00:00<00:00, 265kB/s]

# %%
df = pd.read_csv('/home/amirhosseion/Pr#2/drug200.csv')
df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
# Encode categorical data
df_encoded = pd.get_dummies(df, columns=['Sex', 'BP', 'Cholesterol'], drop_first=True)

# Separate features and target
X = df_encoded.drop('Drug', axis=1)
y = df_encoded['Drug']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, stratify=y, random_state=42)

# %%
X
# Out:
#      Age  Na_to_K  Sex_M  BP_LOW  BP_NORMAL  Cholesterol_NORMAL
# 0     23   25.355  False   False      False               False
# 1     47   13.093   True    True      False               False
# 2     47   10.114   True    True      False               False
# 3     28    7.798  False   False       True               False
# 4     61   18.043  False    True      False               False
# ..   ...      ...    ...     ...        ...                 ...
# 195   56   11.567  False    True      False               False
# 196   16   12.006   True    True      False               False
# 197   52    9.894   True   False       True               False
# 198   23   14.020   True   False       True                True
# 199   40   11.349  False    True      False                True
#
# [200 rows x 6 columns]

# %%
labels = df_encoded['Drug']
labels.unique(), labels.value_counts()
# Out:
# (array(['drugY', 'drugC', 'drugX', 'drugA', 'drugB'], dtype=object),
#  Drug
#  drugY    91
#  drugX    54
#  drugA    23
#  drugC    16
#  drugB    16
#  Name: count, dtype: int64)

# %%
# Initialize the Decision Tree Classifier
model = DecisionTreeClassifier(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cm = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Accuracy: 0.9666666666666667
# Precision: 0.96
# Recall: 0.9
# F1 Score: 0.9111111111111111

# %%
import graphviz
from IPython.display import Image, display
from sklearn import tree

import pydotplus

# %%
tree.plot_tree(model)
# Out:
# [Text(0.75, 0.9, 'x[1] <= 14.829\ngini = 0.696\nsamples = 170\nvalue = [19, 14, 14, 46, 77]'),
#  Text(0.625, 0.7, 'x[4] <= 0.5\ngini = 0.668\nsamples = 93\nvalue = [19, 14, 14, 46, 0]'),
#  Text(0.5, 0.5, 'x[3] <= 0.5\ngini = 0.746\nsamples = 62\nvalue = [19, 14, 14, 15, 0]'),
#  Text(0.25, 0.3, 'x[0] <= 52.0\ngini = 0.489\nsamples = 33\nvalue = [19, 14, 0, 0, 0]'),
#  Text(0.125, 0.1, 'gini = 0.0\nsamples = 19\nvalue = [19, 0, 0, 0, 0]'),
#  Text(0.375, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [0, 14, 0, 0, 0]'),
#  Text(0.75, 0.3, 'x[5] <= 0.5\ngini = 0.499\nsamples = 29\nvalue = [0.0, 0.0, 14.0, 15.0, 0.0]'),
#  Text(0.625, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0]'),
#  Text(0.875, 0.1, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0]'),
#  Text(0.75, 0.5, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 0, 31, 0]'),
#  Text(0.875, 0.7, 'gini = 0.0\nsamples = 77\nvalue = [0, 0, 0, 0, 77]')]

# %% [markdown]
# #### GridSearch

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold



# Define the parameter grid for hyperparameter tuning
param_grid = {
    'max_depth': [3, 5, 7, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5, 10],
    'criterion': ['gini', 'entropy']
}

# Define Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize the Decision Tree Classifier
model = DecisionTreeClassifier(random_state=94)

# Initialize GridSearchCV with Stratified K-Fold Cross-Validation
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=skf, scoring='accuracy', n_jobs=-1, verbose=1)

# Fit the model with GridSearchCV
grid_search.fit(X_train, y_train)

# Print the best parameters and the best score from GridSearchCV
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Score:", grid_search.best_score_)

# Use the best model to predict on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
cm = confusion_matrix(y_test, y_pred)

print(f"Test Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# Best Parameters: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best Cross-Validation Score: 0.9941176470588236
# Test Accuracy: 0.9666666666666667
# Precision: 0.96
# Recall: 0.9
# F1 Score: 0.9111111111111111

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier


# Define the parameter grid for hyperparameter tuning
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Define Stratified K-Fold Cross-Validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize the Random Forest Classifier
rf_model = RandomForestClassifier(random_state=42)

# Initialize GridSearchCV with Stratified K-Fold Cross-Validation
grid_search_rf = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=skf, scoring='accuracy', n_jobs=-1, verbose=1)

# Fit the model with GridSearchCV
grid_search_rf.fit(X_train, y_train)

# Print the best parameters and the best score from GridSearchCV
print("Best Parameters for Random Forest:", grid_search_rf.best_params_)
print("Best Cross-Validation Score for Random Forest:", grid_search_rf.best_score_)

# Use the best model to predict on the test set
best_rf_model = grid_search_rf.best_estimator_
y_pred_rf = best_rf_model.predict(X_test)

# Evaluation metrics
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf, average='macro')
recall_rf = recall_score(y_test, y_pred_rf, average='macro')
f1_rf = f1_score(y_test, y_pred_rf, average='macro')
cm_rf = confusion_matrix(y_test, y_pred_rf)

print(f"Test Accuracy for Random Forest: {accuracy_rf}")
print(f"Precision for Random Forest: {precision_rf}")
print(f"Recall for Random Forest: {recall_rf}")
print(f"F1 Score for Random Forest: {f1_rf}")

# Display confusion matrix
disp_rf = ConfusionMatrixDisplay(confusion_matrix=cm_rf)
disp_rf.plot()
plt.show()
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# Best Parameters for Random Forest: {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best Cross-Validation Score for Random Forest: 0.9882352941176471
# Test Accuracy for Random Forest: 0.9333333333333333
# Precision for Random Forest: 0.7333333333333333
# Recall for Random Forest: 0.8
# F1 Score for Random Forest: 0.76
# /home/amirhosseion/miniconda3/envs/TestPy/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Problem 4
# ## Heart Disease

# %%
# download data set
# !pip install gdown
# !gdown 1GmmqDbkt7_tKf-WmquLwJpVT6NFbAbJp
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1GmmqDbkt7_tKf-WmquLwJpVT6NFbAbJp
# To: /home/amirhosseion/Pr#2/heart.csv
# 100%|██████████████████████████████████████| 38.1k/38.1k [00:00<00:00, 61.1kB/s]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.under_sampling import RandomUnderSampler

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, ConfusionMatrixDisplay

# %%
# load data set
df = pd.read_csv('/home/amirhosseion/Pr#2/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# ### Pre Process

# %%
labels = df['target']
labels.unique(), labels.value_counts()
# Out:
# (array([0, 1]),
#  target
#  1    526
#  0    499
#  Name: count, dtype: int64)

# %%
# Separate features and target
X = df.drop('target', axis=1)
y = df['target']
# Use RandomUnderSampler to balance the classes
rus = RandomUnderSampler(random_state=94)
X_resampled, y_resampled = rus.fit_resample(X, y)

# Count the number of samples in each class after balancing
unique_resampled, counts_resampled = np.unique(y_resampled, return_counts=True)
print("Class counts after balancing:", dict(zip(unique_resampled, counts_resampled)))
print('\n')
print("New balanced dataset shape:", X_resampled.shape, y_resampled.shape)
# Out:
# Class counts after balancing: {0: 499, 1: 499}
#
#
# New balanced dataset shape: (998, 13) (998,)

# %%
X = X_resampled
y = y_resampled
print(X.shape, y.shape)
#Splitting the data into training and test data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=94)
# Out:
# (998, 13) (998,)

# %%
# StandardScaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
print(x_train[:5])
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)
print(x_train[:5])
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 513   54    1   0       110   206    0        0      108      1      0.0
# 697   67    1   2       152   212    0        0      150      0      0.8
# 474   48    1   1       110   229    0        1      168      0      1.0
# 964   44    0   2       108   141    0        1      175      0      0.6
# 833   55    1   0       140   217    0        1      111      1      5.6
#
#      slope  ca  thal
# 513      1   1     2
# 697      1   0     3
# 474      0   0     3
# 964      1   0     2
# 833      0   0     3
# [[-0.04199863  0.65778039 -0.91511828 -1.24342782 -0.7552452  -0.41863795
#   -0.99823309 -1.79832619  1.41821041 -0.9107481  -0.63163779  0.26285325
#   -0.52849061]
#  [ 1.38183743  0.65778039  1.02449496  1.14604106 -0.64045158 -0.41863795
#   -0.99823309  0.03244656 -0.70511399 -0.23943811 -0.63163779 -0.71731915
#    1.08735425]
# ...

# %%
print(y_train.shape)
print(y_train.ravel().shape)
# Out:
# (798,)
# (798,)
# /tmp/ipykernel_380/3210049001.py:2: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   print(y_train.ravel().shape)

# %% [markdown]
# ### NaiveBayes Classifier

# %%
class NaiveBayes:
    def fit(self, X, y):
        n_samples, n_features = X.shape
        self._classes = np.unique(y)
        n_classes = len(self._classes)

        # calculate mean, var, and prior for each class
        self._mean = np.zeros((n_classes, n_features), dtype=np.float64)
        self._var = np.zeros((n_classes, n_features), dtype=np.float64)
        self._priors = np.zeros(n_classes, dtype=np.float64)

        for idx, c in enumerate(self._classes):
            X_c = X[y == c]
            self._mean[idx, :] = X_c.mean(axis=0)
            self._var[idx, :] = X_c.var(axis=0)
            self._priors[idx] = X_c.shape[0] / float(n_samples)
            

    def predict(self, X):
        y_pred = [self._predict(x) for x in X]
        return np.array(y_pred)

    def _predict(self, x):
        posteriors = []

        # calculate posterior probability for each class
        for idx, c in enumerate(self._classes):
            prior = np.log(self._priors[idx])
            posterior = np.sum(np.log(self._pdf(idx, x)))
            posterior = posterior + prior
            posteriors.append(posterior)

        # return class with the highest posterior
        return self._classes[np.argmax(posteriors)]

    def _pdf(self, class_idx, x):
        mean = self._mean[class_idx]
        var = self._var[class_idx]
        numerator = np.exp(-((x - mean) ** 2) / (2 * var))
        denominator = np.sqrt(2 * np.pi * var)
        return numerator / denominator

# %%
from sklearn.naive_bayes import GaussianNB
MyNB = NaiveBayes()
SKNB=GaussianNB()

MyNB.fit(x_train, y_train.ravel())
SKNB.fit(x_train,y_train.ravel())
pred = MyNB.predict(x_test)
pred2 = SKNB.predict(x_test)
# Out:
# /tmp/ipykernel_380/1788195205.py:5: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   MyNB.fit(x_train, y_train.ravel())
# /tmp/ipykernel_380/1788195205.py:6: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   SKNB.fit(x_train,y_train.ravel())

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       108
#            1       0.80      0.86      0.83        92
#
#     accuracy                           0.83       200
#    macro avg       0.83      0.84      0.83       200
# weighted avg       0.84      0.83      0.84       200

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test,pred)
names = list(df.groupby('target').groups.keys())
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=names)
disp.plot()
plt.show()

# %%
import random

#Generate a list of indices for the raveled array
indices = list(range(len(y_test.ravel())))
# Choose five random samples from the raveled array
random_indices = random.sample(indices, 5)

print("true label:", y_test.ravel()[random_indices])
print('pred label:',pred[random_indices])
# Out:
# true label: [1 0 0 0 0]
# pred label: [0 0 0 0 1]
# /tmp/ipykernel_380/3683479794.py:4: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   indices = list(range(len(y_test.ravel())))
# /tmp/ipykernel_380/3683479794.py:8: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   print("true label:", y_test.ravel()[random_indices])
